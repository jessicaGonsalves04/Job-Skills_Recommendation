# %% [markdown]
# <a href="https://colab.research.google.com/github/jessicaGonsalves04/Job-Skills_Recommendation/blob/main/Job_Skill_Recommendation_HDBSCAN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import re
import umap
import hdbscan
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.feature_extraction.text import TfidfVectorizer

# %%
df = pd.read_csv('IT_Job_Roles_Skills.csv', encoding='ISO-8859-1')

# %%
def clean_title(title):
    title = str(title).lower()
    title = re.sub(r'[^a-zA-Z ]', '', title)
    return title.strip()

df['Cleaned_Job_Title'] = df['Job Title'].apply(clean_title)

# %%
title_mappings = {
    'ios developer': ['ios developer', 'junior ios developer', 'ios dev'],
    'android developer': ['android developer'],
    'data scientist': ['data scientist', 'junior data scientist'],
    'data analyst': ['data analyst'],
    'software engineer': ['software engineer', 'junior software engineer', 'entry level software developer'],
    'frontend developer': ['front end developer', 'junior front end developer', 'front end web developer', 'frontend engineer'],
    'ai architect': ['artificial intelligence architect', 'machine learning architect', 'principle engineer in artificial intelligence', 'principle engineer in machine learning'],
    'uiux designer': ['ux designer', 'uxui designer', 'ui user interface designer', 'ui designer', 'ux researcher'],
    'machine learning engineer': ['machine learning engineer', 'ml engineer', 'junior machine learning engineer'],
    'devops engineer': ['devops engineer', 'senior devops engineer', 'devops architect', 'ansible operations engineer', 'kubernetes operations engineer'],
    'cloud architect': ['cloud architect', 'cloud engineer', 'cloud operations engineer'],
}

# %%
title_mappings.update({
    'front end developer': [
        'front end developer',
        'junior front end developer',
        'front end web developer',
        'frontend engineer',
        'frontend developer'
    ],
    'ai architect': [
        'artificial intelligence architect',
        'machine learning architect',
        'principle engineer in artificial intelligence',
        'principle engineer in machine learning'
    ],
    'uiux designer': [
        'ux designer',
        'uxui designer',
        'ui user interface designer',
        'ui designer',
        'ux researcher'
    ],
    'machine learning engineer': [
        'machine learning engineer',
        'ml engineer',
        'junior machine learning engineer'
    ],
    'devops engineer': 'devops engineer',
    'senior devops engineer': 'devops engineer',
    'devops architect': 'devops architect',
    'devsecops architect': 'devsecops architect',  # VALID
    'ansible operations engineer': 'devops engineer',
    'kubernetes operations engineer': 'devops engineer',
    'packer engineer': 'devops engineer',

    'cloud architect': 'cloud architect',
    'cloud security engineer': 'cloud security engineer',

    'chef inspec engineer': 'chief inspec engineer',  # PRESERVED
})

# %%
  title_mappings.update({# UX/UI Variants
    'ux designer': 'ux/ui designer',
    'uxui designer': 'ux/ui designer',
    'ux/ui designer': 'ux/ui designer',
    'ui (user interface) designer': 'ux/ui designer',
    'web designer (ui/ux designer)': 'ux/ui designer',

    # Mobile Development
    'mobile app developer': 'mobile application developer',
    'mobile application developer': 'mobile application developer',

    # Extra Cleanups
    'packer engineer': 'devops engineer',
    'ansible operations engineer': 'devops engineer',
    'chef inspec engineer': 'devsecops engineer',  # corrected
    'chief operations engineer': 'devsecops engineer',  # corrected
  })

# %%
title_mappings.update({
    # UX/UI Variants
    'ux designer': 'ux/ui designer',
    'uxui designer': 'ux/ui designer',
    'ux/ui designer': 'ux/ui designer',
    'ui (user interface) designer': 'ux/ui designer',
    'web designer (ui/ux designer)': 'ux/ui designer',

    # Mobile Development
    'mobile app developer': 'mobile application developer',
    'mobile application developer': 'mobile application developer',

    # Extra Cleanups
    'packer engineer': 'devops engineer',
    'ansible operations engineer': 'devops engineer',
    'chef inspec engineer': 'devsecops engineer',
    'chief operations engineer': 'devsecops engineer',

    # QA/DevOps Testing
    'jacoco engineer': 'qa/devops testing engineer',
    'junit engineer': 'qa/devops testing engineer',
    'qa engineer': 'qa/devops testing engineer',
    'sonarqube engineer': 'qa/devops testing engineer',

    # Monitoring/Observability
    'splunk engineer': 'observability/monitoring engineer',
    'appdynamics engineer': 'observability/monitoring engineer',
    'datadog engineer': 'observability/monitoring engineer',
    'grafana engineer': 'observability/monitoring engineer',
    'new relic engineer': 'observability/monitoring engineer',

    # Front-End Dev
    'entry level web developer': 'front-end developer',
    'front end developer': 'front-end developer',
    'junior front end developer': 'front-end developer',
    'front end web developer': 'front-end developer',
    'javascript developer': 'front-end developer',


    # IT Support
    'production support engineer': 'it support specialist',
    'help desk technician': 'it support specialist',
    'computer support specialist': 'it support specialist',
    'technology assistant': 'it support specialist',
    'it support specialist': 'it support specialist',

    # Database Roles
    'oracle developer': 'database specialist',
    'oracle sql developer': 'database specialist',
    'database administrator': 'database specialist',
    'sql developer': 'database specialist',
    'database architect': 'database specialist',

    # AI/ML Architects
    'artificial intelligence machine learning leader': 'ai/ml architect',
    'artificial intelligence architect': 'ai/ml architect',
    'machine learning architect': 'ai/ml architect',
    'principle engineer in artificial intelligence': 'ai/ml architect',
    'principle engineer in machine learning': 'ai/ml architect',


    # Cybersecurity
    'information security analyst': 'cybersecurity specialist',
    'cybersecurity analyst': 'cybersecurity specialist',
    'cybersecurity specialist': 'cybersecurity specialist',
    'cybersecurity engineer': 'cybersecurity specialist',
    'infosec analystcybersecurity analyst': 'cybersecurity specialist',

    # Big Data
    'admin big data': 'big data specialist',
    'big data architect': 'big data specialist',
    'big data specialist': 'big data specialist',
    'principle engineer in big data': 'big data specialist',
    'data architect': 'big data specialist',

    # UX Group
    'interaction designer': 'ux/ui designer',
    'information architect': 'ux/ui designer',

    # Programming General
    'coder': 'programmer',
    'computer programmer': 'programmer',
    'developer': 'programmer',
    'entry level programmer': 'programmer',
    'programmer': 'programmer',

    # Entry-Level Engineering
    'entry level developer': 'entry-level software developer',
    'entry level software developer': 'entry-level software developer',
    'entry level software engineer': 'entry-level software developer',
    'full stack python developerprogrammerengineer': 'entry-level software developer',
    'jr developer': 'entry-level software developer',

    # Management Roles
    'devops manager': 'engineering manager',
    'director of engineering': 'engineering manager',
    'it manager': 'engineering manager',
    'chief information officer': 'engineering manager',
    'technology manager': 'engineering manager',

    # Cloud & Infra
    'cloud architect': 'cloud/infra architect',
    'devops architect': 'cloud/infra architect',
    'senior devops engineer': 'cloud/infra architect',
    'infrastructure architect': 'cloud/infra architect',
    'cloud computing specialist': 'cloud/infra architect',

    # Sysadmin & Ops
    'operations engineer': 'systems administrator',
    'network and systems administrator': 'systems administrator',
    'systems administrator': 'systems administrator',
    'systems engineer': 'systems administrator',
    'cloud administrator': 'systems administrator',

    # Build & Release
    'bamboo engineer': 'build and release engineer',
    'build and release engineer': 'build and release engineer',
    'build engineer': 'build and release engineer',
    'jenkins engineer': 'build and release engineer',
    'senior build and release engineer': 'build and release engineer',
    'artifactory administrator': 'build and release engineer'
})

# %%
def clean_skills(text):
    if pd.isna(text): return ""
    text = text.lower()

    # Join known multi-word phrases first
    multi_word_skills = {
        'version control': 'version_control',
        'machine learning': 'machine_learning',
        'deep learning': 'deep_learning',
        'natural language processing': 'nlp',
        'data analysis': 'data_analysis',
        'data science': 'data_science',
        'object oriented programming': 'oop',
        'software development life cycle': 'sdlc'
    }

    for phrase, replacement in multi_word_skills.items():
        text = text.replace(phrase, replacement)

    # Continue with your cleaning
    text = re.sub(r'[^\w\s]', ' ', text)
    text = re.sub(r'\s+', ' ', text)
    return text.strip()


df['Cleaned_Skills'] = df['Skills'].apply(clean_skills)

# %%
skill_mapping = {
    # Programming Languages
    'python3': 'python',
    'python 3': 'python',
    'python-3': 'python',
    'core java': 'java',
    'java se': 'java',
    'java programming': 'java',
    'js': 'javascript',
    'java script': 'javascript',
    'javascript.js': 'javascript',
    'cpp': 'c++',
    'c plus plus': 'c++',
    'c-sharp': 'c#',
    'c sharp': 'c#',
    '.net c#': 'c#',
    'ruby on rails': 'ruby',
    'ror': 'ruby',
    'php7': 'php',
    'php 7': 'php',
    'php5': 'php',

    # Web Development
    'html5': 'html',
    'html 5': 'html',
    'css3': 'css',
    'css 3': 'css',
    'bootstrap4': 'bootstrap',
    'bootstrap 4': 'bootstrap',
    'node js': 'nodejs',
    'node.js': 'nodejs',
    'node': 'nodejs',
    'react': 'reactjs',
    'react js': 'reactjs',
    'react.js': 'reactjs',
    'angularjs': 'angular',
    'angular.js': 'angular',
    'angular 2+': 'angular',
    'vue': 'vuejs',
    'vue.js': 'vuejs',
    'django rest framework': 'django',
    'drf': 'django',

    # Cloud & DevOps
    'amazon web services': 'aws',
    'aws cloud': 'aws',
    'google cloud': 'gcp',
    'google cloud platform': 'gcp',
    'microsoft azure': 'azure',
    'jenkins ci': 'jenkins',
    'jenkins pipeline': 'jenkins',
    'docker containers': 'docker',
    'k8s': 'kubernetes',
    'ansible automation': 'ansible',
    'terraform cloud': 'terraform',

    # Data & Analytics
    'ms excel': 'excel',
    'microsoft excel': 'excel',
    'powerbi': 'power bi',
    'tableau desktop': 'tableau',
    'mysql': 'sql',
    'postgresql': 'sql',
    'mssql': 'sql',
    'sql server': 'sql',
    'np': 'numpy',
    'pd': 'pandas',
    'scientific python': 'scipy',

    # Machine Learning / AI
    'ml': 'machine learning',
    'dl': 'deep learning',
    'natural language processing': 'nlp',
    'cv': 'computer vision',
    'tf': 'tensorflow',
    'keras api': 'keras',
    'sklearn': 'scikit-learn',
    'data scientist': 'data science',
    'data analyst': 'data analysis',

    # Tools & Platforms
    'github': 'git',
    'gitlab': 'git',
    'atlassian jira': 'jira',
    'ubuntu': 'linux',
    'centos': 'linux',
    'red hat': 'linux',
    'visual studio code': 'vs code',
    '.net,':'.net',

    'ui/ux basics':'ui/ux',
    'ui/ux design':'ui/ux',
    'basic web development':'web-dev basics',
    'web development fundamentals':'web-dev basics',
    ' problem solving':'problem solving'

}

# %%
def map_skills(skill_text):
    if pd.isna(skill_text):
        return ""
    skills = [s.strip().lower() for s in skill_text.split(',')]
    mapped = [skill_mapping.get(s, s) for s in skills]
    return ', '.join(sorted(set(mapped)))

df['Cleaned_Skills'] = df['Skills'].apply(map_skills)

# %%
vectorizer = TfidfVectorizer(max_features=1000, stop_words='english')
X_skills = vectorizer.fit_transform(df['Cleaned_Skills'])
#2nd attempt code

# %%
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(df['Cleaned_Skills'])

# %%
reducer = umap.UMAP(n_neighbors=15, min_dist=0.1, metric='cosine', random_state=42)
X_umap = reducer.fit_transform(X_skills)
#2nd attempt code
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(

# %%
clusterer = hdbscan.HDBSCAN(min_cluster_size=5, metric='euclidean')
cluster_labels = clusterer.fit_predict(X_umap)

df['Skill_Cluster'] = cluster_labels
#2nd attempt code
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(

# %%
plt.figure(figsize=(15, 10))

# Create a custom color palette with 31 distinct colors
import matplotlib.colors as mcolors
import numpy as np

# Combine multiple color palettes to get enough distinct colors
base_colors = []
base_colors.extend(plt.cm.tab10.colors)  # 10 colors
base_colors.extend(plt.cm.Set1.colors)   # 9 colors
base_colors.extend(plt.cm.Set2.colors)   # 8 colors
base_colors.extend(plt.cm.Set3.colors)   # 12 colors
base_colors.extend(plt.cm.Dark2.colors)  # 8 colors

# Ensure we have at least 31 unique colors
unique_colors = list(dict.fromkeys([tuple(c) for c in base_colors]))[:31]
# Fill with additional random colors if needed
while len(unique_colors) < 31:
    new_color = tuple(np.random.random(3).tolist() + [1.0])  # RGB + alpha
    if new_color not in unique_colors:
        unique_colors.append(new_color)

# Create sorted list of clusters excluding noise (-1)
unique_clusters = sorted([c for c in df['Skill_Cluster'].unique() if c != -1])
n_clusters = len(unique_clusters)

# Create color dictionary for clusters
cluster_colors = {}
for i, cluster in enumerate(unique_clusters):
    cluster_colors[cluster] = unique_colors[i % len(unique_colors)]

# Handle noise cluster if it exists
if -1 in df['Skill_Cluster'].unique():
    cluster_colors[-1] = (0.8, 0.8, 0.8, 0.3)  # Light gray with transparency for noise

# Plot with custom colors
scatter = plt.scatter(X_umap[:, 0], X_umap[:, 1],
                     c=[cluster_colors.get(c, (0,0,0)) for c in df['Skill_Cluster']],
                     s=50, alpha=0.7)

# Create custom legend
legend_elements = [plt.Line2D([0], [0], marker='o', color='w',
                             markerfacecolor=cluster_colors[c],
                             markersize=10, label=f'Cluster {c}')
                  for c in unique_clusters]

# Add noise to legend if it exists
if -1 in df['Skill_Cluster'].unique():
    legend_elements.append(plt.Line2D([0], [0], marker='o', color='w',
                                     markerfacecolor=cluster_colors[-1],
                                     markersize=10, label='Noise (-1)'))

plt.legend(handles=legend_elements, bbox_to_anchor=(1.05, 1), loc='upper left', fontsize=8)
plt.title('HDBSCAN Clusters of Job Skills', fontsize=16)
plt.xlabel('UMAP Dimension 1', fontsize=12)
plt.ylabel('UMAP Dimension 2', fontsize=12)
plt.tight_layout()
plt.grid(True, linestyle='--', alpha=0.7)
plt.show()

# %%
for cluster_id in sorted(df['Skill_Cluster'].unique()):
    cluster_df = df[df['Skill_Cluster'] == cluster_id]
    print(f"\n🔹 Cluster {cluster_id} ({len(cluster_df)} items)")
    print(cluster_df['Cleaned_Job_Title'].value_counts().head(10))
    print("Top Skills:", cluster_df['Cleaned_Skills'].str.split(',').explode().value_counts().head(10).to_dict())
#2nd attempt code
# Out:
# 🔹 Cluster -1 (65 items)
# Cleaned_Job_Title
# cnc programmer                 2
# computer research scientist    2
# computer network architect     2
# network engineer               2
# mulesoft developer             2
# java developer                 2
# full stack developer           2
# octopus deploy engineer        2
# nomad engineer                 2
# xl deploy engineer             2
# Name: count, dtype: int64
# Top Skills: {' cloud computing': 8, ' java': 8, ' system architecture': 8, ' devops practices': 7, ' security': 7, ' sql': 5, ' python': 5, ' machine learning': 5, 'data analysis': 5, 'cloud computing': 5}
#
# 🔹 Cluster 0 (14 items)
# Cleaned_Job_Title
# coveragepy engineer                   2
# fortify engineer                      2
# jacoco engineer                       2
# junit engineer                        2
# pytest engineer                       1
# qa engineer                           1
# selenium engineer                     1
# sonarqube engineer                    1
# quality assurance manager             1
# software quality assurance analyst    1
# Name: count, dtype: int64
# Top Skills: {' test automation': 6, 'ci/cd': 5, ' java': 5, ' testing': 4, ' python': 4, ' static code analysis': 3, ' junit': 3, ' software quality': 3, ' security': 2, ' code coverage': 2}
#
# 🔹 Cluster 1 (10 items)
# Cleaned_Job_Title
# android developer               2
# ios developer                   2
# junior ios developer            2
# mobile app developer            2
# mobile application developer    1
# mobile developer                1
# Name: count, dtype: int64
# Top Skills: {' ui/ux': 9, ' objective-c': 6, ' swift': 6, ' mobile development': 4, 'android sdk': 4, ' kotlin': 4, ' java': 4, ' mobile app development': 4, ' programming languages': 2, ' rest apis': 2}
#
# 🔹 Cluster 2 (18 items)
# Cleaned_Job_Title
# computer graphics animator    2
# game developer                2
# d artistanimator              2
# unity developer               1
# animator                      1
# motion graphics artist        1
# character designer            1
# storyboard artist             1
# vfx artist                    1
# rigging artist                1
# Name: count, dtype: int64
# Top Skills: {'3d modeling': 8, ' visual effects': 7, ' storyboarding': 3, ' animation software': 3, ' animation': 3, ' compositing': 3, ' game design': 2, '2d animation': 2, ' motion graphics': 2, ' c#': 2}
#
# 🔹 Cluster 3 (7 items)
# Cleaned_Job_Title
# c developer                     2
# net developer                   1
# sharepoint developer            1
# tfs engineer                    1
# microsoft dynamics developer    1
# manager net                     1
# Name: count, dtype: int64
# Top Skills: {'.net': 4, ' c#': 4, ' asp.net': 3, ' cloud computing': 2, ' entity framework': 2, ' git': 2, ' linq': 2, ' mvc': 2, ' sql': 2, ' web api': 2}
#
# 🔹 Cluster 4 (8 items)
# Cleaned_Job_Title
# elk engineer        3
# splunk engineer     3
# fluentd engineer    2
# Name: count, dtype: int64
# Top Skills: {' log management': 7, ' linux': 4, ' azure': 4, ' security': 4, ' kibana': 3, ' splunk': 3, ' system monitoring': 3, ' elasticsearch': 3, 'aws': 2, ' networking': 2}
#
# 🔹 Cluster 5 (26 items)
# Cleaned_Job_Title
# gerrit administrator          2
# git engineer                  2
# bitbucket engineer            2
# jenkins engineer              2
# groovy engineer               2
# github engineer               2
# artifactory administrator     1
# build and release engineer    1
# build engineer                1
# senior build engineer         1
# Name: count, dtype: int64
# Top Skills: {' git': 20, ' version control': 20, ' ci/cd': 18, ' scripting': 14, 'automation': 12, ' linux': 10, ' jenkins': 9, ' build automation': 9, ' maven': 8, ' gradle': 8}
#
# 🔹 Cluster 6 (9 items)
# Cleaned_Job_Title
# database administrator    2
# oracle developer          2
# oracle sql developer      2
# sql developer             1
# database architect        1
# database developer        1
# Name: count, dtype: int64
# Top Skills: {' sql': 8, ' performance tuning': 6, ' pl/sql': 5, ' database design': 4, 'data modeling': 4, ' etl': 3, 'backup and recovery': 2, ' database management': 2, 'database development': 2, ' oracle': 2}
#
# 🔹 Cluster 7 (6 items)
# Cleaned_Job_Title
# entry level web developer     2
# junior web developer          1
# accessibility specialist      1
# junior front end developer    1
# web developer                 1
# Name: count, dtype: int64
# Top Skills: {'css': 6, ' html': 6, ' javascript': 6, ' web-dev basics': 4, ' git': 2, ' ui/ux': 2, ' learning agility': 2, ' user experience design': 1, ' web accessibility guidelines': 1, ' frameworks': 1}
#
# 🔹 Cluster 8 (11 items)
# Cleaned_Job_Title
# front end developer           2
# accessibility specialist      1
# blockchain developer          1
# front end web developer       1
# javascript developer          1
# junior front end developer    1
# react developer               1
# ui developer                  1
# web developer                 1
# frontend designer             1
# Name: count, dtype: int64
# Top Skills: {' javascript': 11, ' html': 10, ' ui/ux': 8, ' reactjs': 7, ' css': 6, ' nodejs': 6, 'angular': 5, ' vuejs': 4, 'css': 4, ' sass': 3}
#
# 🔹 Cluster 9 (19 items)
# Cleaned_Job_Title
# full stack java developerprogrammerengineer      2
# full stack python developerprogrammerengineer    2
# php developer                                    2
# python developer                                 2
# entry level software developer                   1
# entry level software engineer                    1
# entry level developer                            1
# junior developer                                 1
# jr developer                                     1
# junior software engineer                         1
# Name: count, dtype: int64
# Top Skills: {' html': 15, ' sql': 15, ' javascript': 15, ' git': 13, ' python': 12, ' css': 10, ' data structures': 10, 'algorithms': 10, ' java': 10, 'css': 5}
#
# 🔹 Cluster 10 (8 items)
# Cleaned_Job_Title
# computer programmer       2
# coder                     1
# developer                 1
# entry level programmer    1
# programmer                1
# software developer        1
# software engineer         1
# Name: count, dtype: int64
# Top Skills: {'algorithms': 8, ' data structures': 7, ' debugging': 7, ' programming': 6, ' software development': 6, ' c++': 6, ' java': 6, ' python': 6, ' problem solving': 1, ' ci/cd': 1}
#
# 🔹 Cluster 11 (13 items)
# Cleaned_Job_Title
# coder                               1
# entry level developer               1
# entry level programmer              1
# frameworks specialist               1
# api developer                       1
# internet of things iot developer    1
# back end developer                  1
# software architect                  1
# cloudsoftware developer             1
# software development engineer       1
# Name: count, dtype: int64
# Top Skills: {' programming languages': 10, ' software development': 6, ' problem solving': 3, 'problem solving': 2, 'learning agility': 2, ' programming basics': 2, ' scripting': 1, ' software frameworks': 1, ' system design': 1, 'api design': 1}
#
# 🔹 Cluster 12 (9 items)
# Cleaned_Job_Title
# production support engineer        1
# help desk technician               1
# computer support specialist        1
# technology assistant               1
# technology specialist              1
# it support specialist              1
# customer service representative    1
# it apprentice                      1
# it technician                      1
# Name: count, dtype: int64
# Top Skills: {' technical support': 8, ' troubleshooting': 8, 'customer service': 4, ' hardware/software': 4, ' problem solving': 2, ' system monitoring': 1, 'incident management': 1, 'administrative support': 1, 'it support': 1, ' technical expertise': 1}
#
# 🔹 Cluster 13 (11 items)
# Cleaned_Job_Title
# interaction designer          2
# information architect         1
# ui designer                   1
# ux designer                   1
# web designer uiux designer    1
# uxui designer                 1
# web designer                  1
# ui user interface designer    1
# uxui researcher               1
# uxui specialist               1
# Name: count, dtype: int64
# Top Skills: {' user research': 8, ' usability testing': 7, ' prototyping': 6, ' wireframing': 6, ' ui/ux': 3, 'interaction design': 3, 'prototyping': 3, ' figma': 2, 'adobe creative suite': 2, ' ux/ui design': 2}
#
# 🔹 Cluster 14 (8 items)
# Cleaned_Job_Title
# computer hardware engineer    2
# embedded software engineer    2
# robotics engineer             1
# embedded systems engineer     1
# mainframe developer           1
# firmware manager              1
# Name: count, dtype: int64
# Top Skills: {' embedded systems': 5, ' firmware development': 4, ' testing': 3, ' hardware design': 3, 'circuit design': 2, 'c/c++': 2, ' hardware interfaces': 2, ' microprocessors': 1, 'communication protocols': 1, ' embedded c': 1}
#
# 🔹 Cluster 15 (14 items)
# Cleaned_Job_Title
# business systems analyst             2
# computer systems analyst             2
# programmer analyst                   1
# product manager                      1
# automation specialist                1
# digital transformation consultant    1
# erp consultant                       1
# sap consultant                       1
# information technology analyst       1
# requirements manager                 1
# Name: count, dtype: int64
# Top Skills: {' requirements gathering': 9, ' process improvement': 7, ' sql': 3, ' uml': 2, 'data analysis': 2, ' stakeholder management': 2, 'market analysis': 2, 'business process analysis': 2, ' implementation': 2, ' data analysis': 1}
#
# 🔹 Cluster 16 (11 items)
# Cleaned_Job_Title
# big data specialist                           2
# principle engineer in data analysis           2
# data analyst                                  2
# data analysts                                 1
# business intelligence analyst                 1
# geographic information systems gis analyst    1
# power bi developer                            1
# power bi analyst                              1
# Name: count, dtype: int64
# Top Skills: {' data visualization': 9, ' sql': 8, ' data mining': 4, ' data modeling': 4, ' data analysis': 4, ' power bi': 4, ' etl': 3, ' python': 3, ' statistics': 3, 'data analysis': 3}
#
# 🔹 Cluster 17 (13 items)
# Cleaned_Job_Title
# machine learning engineer                        3
# principle engineer in machine learning           2
# machine learning architect                       2
# artificial intelligence architect                1
# artificial intelligence researcher               1
# principle engineer in artificial intelligence    1
# data scientist                                   1
# natural language processing engineer             1
# machine learning engineer for cybersecurity      1
# Name: count, dtype: int64
# Top Skills: {' machine learning': 8, ' deep learning': 7, ' python': 7, ' data science': 5, ' tensorflow': 5, ' model deployment': 4, ' machine learning algorithms': 4, ' data analysis': 4, ' cloud computing': 3, ' pytorch': 3}
#
# 🔹 Cluster 18 (9 items)
# Cleaned_Job_Title
# artificial intelligence  machine learning leader      1
# artificial intelligence  machine learning srleader    1
# artificial intelligence architect                     1
# artificial intelligence researcher                    1
# principle engineer in artificial intelligence         1
# artificial intelligence engineer                      1
# computer and information research scientist           1
# ai researcher                                         1
# ai software architect                                 1
# Name: count, dtype: int64
# Top Skills: {' leadership': 3, 'ai/ml algorithms': 3, ' research methodologies': 3, ' python': 3, 'ai/ml frameworks': 2, ' data analysis': 2, ' deep learning': 2, ' strategic planning': 2, ' data modeling': 2, 'ai/ml architecture': 2}
#
# 🔹 Cluster 19 (7 items)
# Cleaned_Job_Title
# application security engineer                2
# information security analyst                 1
# security specialist                          1
# identity and access management specialist    1
# mobile security specialist                   1
# penetration tester                           1
# Name: count, dtype: int64
# Top Skills: {' penetration testing': 6, ' vulnerability management': 3, ' security protocols': 3, ' security auditing': 2, ' ids/ips': 2, ' network security': 2, 'firewalls': 2, ' security': 2, ' secure coding': 1, ' sast': 1}
#
# 🔹 Cluster 20 (16 items)
# Cleaned_Job_Title
# splunk enterprise security engineer     1
# information security analyst            1
# cybersecurity analyst                   1
# it auditor                              1
# cybersecurity specialist                1
# cybersecurity engineer                  1
# infosec analystcybersecurity analyst    1
# computer forensic analyst               1
# it security specialist                  1
# security manager                        1
# Name: count, dtype: int64
# Top Skills: {'compliance': 10, ' security protocols': 8, ' threat analysis': 8, ' risk management': 7, ' incident response': 6, 'incident response': 4, ' risk assessment': 2, ' security information and event management (siem)': 1, ' threat detection': 1, ' splunk enterprise security': 1}
#
# 🔹 Cluster 21 (6 items)
# Cleaned_Job_Title
# search engine optimization    1
# ecommerce developer           1
# web producer                  1
# web content manager           1
# seo consultant                1
# webmaster                     1
# Name: count, dtype: int64
# Top Skills: {' seo': 2, ' keyword research': 2, ' content strategy': 2, ' web development': 2, ' content marketing': 1, 'analytics': 1, ' on-page optimization': 1, ' off-page optimization': 1, ' payment gateways': 1, 'e-commerce platforms': 1}
#
# 🔹 Cluster 22 (10 items)
# Cleaned_Job_Title
# admin big data                    2
# big data architect                2
# principle engineer in big data    2
# big data engineer                 1
# data architect                    1
# data engineer                     1
# data quality engineer             1
# Name: count, dtype: int64
# Top Skills: {' data warehousing': 9, ' hadoop': 8, ' spark': 8, ' etl': 5, ' sql': 5, ' nosql': 4, ' data governance': 4, ' cloud computing': 4, ' data modeling': 4, ' kafka': 3}
#
# 🔹 Cluster 23 (6 items)
# Cleaned_Job_Title
# data modeler                             1
# big data engineer                        1
# data architect                           1
# data engineer                            1
# data warehouse manager                   1
# data warehouse programming specialist    1
# Name: count, dtype: int64
# Top Skills: {' data warehousing': 5, ' etl processes': 5, 'data modeling': 3, ' database management': 2, ' sql': 2, ' database design': 2, ' er diagrams': 1, ' data modeling': 1, 'data governance': 1, 'data processing': 1}
#
# 🔹 Cluster 24 (7 items)
# Cleaned_Job_Title
# artifactory administrator    1
# aws devops engineer          1
# azure devops engineer        1
# gcp devops engineer          1
# gitlab engineer              1
# jenkins engineer             1
# nexus engineer               1
# Name: count, dtype: int64
# Top Skills: {' devops practices': 6, ' ci/cd pipelines': 5, 'automation': 3, ' devops tools': 1, 'artifactory': 1, ' repository management': 1, ' aws services': 1, ' azure services': 1, ' gcp': 1, 'ci/cd pipelines': 1}
#
# 🔹 Cluster 25 (7 items)
# Cleaned_Job_Title
# bamboo engineer                      1
# build and release engineer           1
# build engineer                       1
# gradle engineer                      1
# senior build and release engineer    1
# senior build engineer                1
# release manager                      1
# Name: count, dtype: int64
# Top Skills: {' build systems': 4, 'automation': 4, ' software configuration management': 4, ' ci/cd pipelines': 3, ' configuration management': 2, ' scripting': 2, ' build automation': 1, 'bamboo': 1, 'build automation': 1, ' gradle': 1}
#
# 🔹 Cluster 26 (59 items)
# Cleaned_Job_Title
# devops engineer                                 3
# devops architect                                2
# chef operations engineer                        2
# ansible automation engineer                     2
# puppet operations engineer                      2
# senior devops engineer                          2
# site reliability engineer kubernetes  docker    2
# devsecops engineer                              2
# envoy engineer                                  2
# consul engineer                                 2
# Name: count, dtype: int64
# Top Skills: {' docker': 32, ' kubernetes': 30, ' networking': 28, ' cloud computing': 28, ' linux': 27, ' ci/cd': 27, ' azure': 25, 'automation': 25, ' aws': 22, ' terraform': 17}
#
# 🔹 Cluster 27 (6 items)
# Cleaned_Job_Title
# technical account manager      2
# tech sales engineer            1
# technology sales consultant    1
# it sales executive             1
# it sales director              1
# Name: count, dtype: int64
# Top Skills: {' sales': 3, 'customer relationship management': 3, ' technical support': 2, 'account management': 2, ' sales strategy': 2, ' technology solutions': 2, 'customer engagement': 1, ' networking technologies': 1, ' project management': 1, ' customer relationship management (crm)': 1}
#
# 🔹 Cluster 28 (42 items)
# Cleaned_Job_Title
# jira administrator         2
# agile project manager      2
# confluence engineer        2
# devops manager             2
# director of engineering    2
# it manager                 2
# technical lead             2
# jira engineer              1
# product manager            1
# web project manager        1
# Name: count, dtype: int64
# Top Skills: {' project management': 29, ' team leadership': 23, 'budgeting': 10, 'agile methodologies': 9, 'communication': 6, ' leadership': 6, ' communication': 5, ' jira': 4, ' software development': 4, ' workflow configuration': 4}
#
# 🔹 Cluster 29 (11 items)
# Cleaned_Job_Title
# datadog engineer        2
# grafana engineer        2
# new relic engineer      2
# zabbix engineer         2
# appdynamics engineer    1
# prometheus engineer     1
# network analyst         1
# Name: count, dtype: int64
# Top Skills: {' cloud computing': 6, ' metrics': 5, ' troubleshooting': 5, ' monitoring': 5, 'alerting': 4, ' application performance monitoring': 2, '.net': 2, ' datadog': 2, ' java': 2, ' alerting': 2}
#
# 🔹 Cluster 30 (14 items)
# Cleaned_Job_Title
# operations engineer                  2
# powershell engineer                  2
# network and systems administrator    2
# entry level network engineer         1
# production support engineer          1
# nagios engineer                      1
# systems administrator                1
# systems engineer                     1
# linux administrator                  1
# it systems administrator             1
# Name: count, dtype: int64
# Top Skills: {' scripting': 10, ' troubleshooting': 10, ' system administration': 8, ' networking': 8, ' windows server': 5, ' linux': 4, 'automation': 4, ' monitoring': 3, ' windows server administration': 3, 'linux/windows servers': 3}
#
# 🔹 Cluster 31 (13 items)
# Cleaned_Job_Title
# aws solutions architect       1
# cloud administrator           1
# cloud architect               1
# cloud network engineer        1
# openstack engineer            1
# cloud migration specialist    1
# infrastructure architect      1
# internet engineer             1
# cloud computing specialist    1
# cloudsoftware architect       1
# Name: count, dtype: int64
# Top Skills: {'cloud platforms': 6, ' system administration': 5, ' security': 5, ' networking': 5, ' virtualization': 4, ' devops': 3, 'cloud computing': 3, ' system architecture': 3, ' cloud security': 3, ' cloud platforms': 2}

# %%
from sklearn.metrics import silhouette_score
import numpy as np

# Assuming 'X_umap' contains your UMAP embeddings and 'cluster_labels' your cluster labels
# Filter out noise points labeled as -1 (HDBSCAN labels noise as -1)
mask = cluster_labels != -1
filtered_embeddings = X_umap[mask]
filtered_labels = cluster_labels[mask]

# Check if there are at least 2 clusters after filtering
unique_clusters = np.unique(filtered_labels)
if len(unique_clusters) > 1:
    # Compute the silhouette score
    score = silhouette_score(filtered_embeddings, filtered_labels)
    print(f"Silhouette Score: {score:.3f}")
else:
    print(f"Cannot calculate silhouette score - only {len(unique_clusters)} cluster(s) after filtering")
# Out:
# Silhouette Score: 0.657

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Explode skills into separate rows
df_exploded = df.copy()
df_exploded['Skill_List'] = df_exploded['Cleaned_Skills'].str.split(',')
df_exploded = df_exploded.explode('Skill_List')

# Strip any extra whitespace
df_exploded['Skill_List'] = df_exploded['Skill_List'].str.strip()

# Loop through clusters
for cluster_id in sorted(df['Skill_Cluster'].unique()):
    if cluster_id == -1:
        continue  # Skip noise points if desired

    cluster_data = df_exploded[df_exploded['Skill_Cluster'] == cluster_id]

    # Get top skills in the cluster
    top_skills = cluster_data['Skill_List'].value_counts().head(10)

    # Plotting
    plt.figure(figsize=(10, 6))
    sns.barplot(x=top_skills.values, y=top_skills.index, palette='viridis')
    plt.title(f"Top 10 Skills in Cluster {cluster_id}")
    plt.xlabel("Frequency")
    plt.ylabel("Skill")
    plt.tight_layout()
    plt.show()
# Out:
# <ipython-input-21-7ad22f0864af>:25: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_skills.values, y=top_skills.index, palette='viridis')
# <ipython-input-21-7ad22f0864af>:25: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_skills.values, y=top_skills.index, palette='viridis')
# <ipython-input-21-7ad22f0864af>:25: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_skills.values, y=top_skills.index, palette='viridis')
# <ipython-input-21-7ad22f0864af>:25: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_skills.values, y=top_skills.index, palette='viridis')
# <ipython-input-21-7ad22f0864af>:25: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_skills.values, y=top_skills.index, palette='viridis')
# <ipython-input-21-7ad22f0864af>:25: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_skills.values, y=top_skills.index, palette='viridis')
# <ipython-input-21-7ad22f0864af>:25: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_skills.values, y=top_skills.index, palette='viridis')
# <ipython-input-21-7ad22f0864af>:25: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_skills.values, y=top_skills.index, palette='viridis')
# <ipython-input-21-7ad22f0864af>:25: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_skills.values, y=top_skills.index, palette='viridis')
# <ipython-input-21-7ad22f0864af>:25: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_skills.values, y=top_skills.index, palette='viridis')
# <ipython-input-21-7ad22f0864af>:25: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_skills.values, y=top_skills.index, palette='viridis')
# <ipython-input-21-7ad22f0864af>:25: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_skills.values, y=top_skills.index, palette='viridis')
# <ipython-input-21-7ad22f0864af>:25: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_skills.values, y=top_skills.index, palette='viridis')
# <ipython-input-21-7ad22f0864af>:25: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_skills.values, y=top_skills.index, palette='viridis')
# <ipython-input-21-7ad22f0864af>:25: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_skills.values, y=top_skills.index, palette='viridis')
# <ipython-input-21-7ad22f0864af>:25: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_skills.values, y=top_skills.index, palette='viridis')
# <ipython-input-21-7ad22f0864af>:25: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_skills.values, y=top_skills.index, palette='viridis')
# <ipython-input-21-7ad22f0864af>:25: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_skills.values, y=top_skills.index, palette='viridis')
# <ipython-input-21-7ad22f0864af>:25: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_skills.values, y=top_skills.index, palette='viridis')
# <ipython-input-21-7ad22f0864af>:25: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_skills.values, y=top_skills.index, palette='viridis')
# <ipython-input-21-7ad22f0864af>:25: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_skills.values, y=top_skills.index, palette='viridis')
# <ipython-input-21-7ad22f0864af>:25: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_skills.values, y=top_skills.index, palette='viridis')
# <ipython-input-21-7ad22f0864af>:25: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_skills.values, y=top_skills.index, palette='viridis')
# <ipython-input-21-7ad22f0864af>:25: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_skills.values, y=top_skills.index, palette='viridis')
# <ipython-input-21-7ad22f0864af>:25: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_skills.values, y=top_skills.index, palette='viridis')
# <ipython-input-21-7ad22f0864af>:25: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_skills.values, y=top_skills.index, palette='viridis')
# <ipython-input-21-7ad22f0864af>:25: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_skills.values, y=top_skills.index, palette='viridis')
# <ipython-input-21-7ad22f0864af>:25: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_skills.values, y=top_skills.index, palette='viridis')
# <ipython-input-21-7ad22f0864af>:25: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_skills.values, y=top_skills.index, palette='viridis')
# <ipython-input-21-7ad22f0864af>:25: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_skills.values, y=top_skills.index, palette='viridis')
# <ipython-input-21-7ad22f0864af>:25: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_skills.values, y=top_skills.index, palette='viridis')
# <ipython-input-21-7ad22f0864af>:25: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_skills.values, y=top_skills.index, palette='viridis')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Split skills into lists and explode into separate rows
df_cluster1 = df[df['Skill_Cluster'] == 9].copy()
df_cluster1['Skill_List'] = df_cluster1['Cleaned_Skills'].str.split(',')
df_cluster1 = df_cluster1.explode('Skill_List')

# Remove leading/trailing spaces from skill names
df_cluster1['Skill_List'] = df_cluster1['Skill_List'].str.strip()

# Count the top 10 skills in Cluster 1
top_skills_cluster1 = df_cluster1['Skill_List'].value_counts().head(10)

# Plotting
plt.figure(figsize=(10, 6))
sns.barplot(x=top_skills_cluster1.values, y=top_skills_cluster1.index, palette='coolwarm')
plt.title("Top 10 Skills in  Web Developement")
plt.xlabel("Frequency")
plt.ylabel("Skill")
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-21-5fa85fb96914>:18: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_skills_cluster1.values, y=top_skills_cluster1.index, palette='coolwarm')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Filter data for Cluster 1 (example)
cluster_id = 1
cluster_data = df[df['Skill_Cluster'] == cluster_id]

# Count the most frequent job titles
title_counts = cluster_data['Cleaned_Job_Title'].value_counts().head(10)  # top 10 titles

# Plotting
plt.figure(figsize=(10, 6))
sns.barplot(x=title_counts.values, y=title_counts.index, palette='viridis')
plt.title(f'Top Job Titles in Cluster {cluster_id} - "App Development"')
plt.xlabel('Frequency')
plt.ylabel('Job Title')
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-24-48fe7618a648>:14: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=title_counts.values, y=title_counts.index, palette='viridis')
